# %% [markdown]
# ## Assignment 1: Part-of-Speech Tagging Using Hidden Markov Model (HMM)
#
# ## Objective:
# Implemented a Part-of-speech tagging system using a Hidden Markov Model (HMM). The datasets contain sentences where each word is paired with its corresponding PoS tag. The goal is to correctly tag words in sentences by leveraging the Viterbi algorithm.

# %% [markdown]
# # Loading Training Corpus

# %%
import pandas as pd

file_path = "https://raw.githubusercontent.com/girishofficial/Viterbi_algorithm/refs/heads/main/TRAIN.csv"
df = pd.read_csv(file_path,names=["sen"])

# %%
df
# Out:
#                                                      sen
# 0      [('03/01/2001', 'NUM'), ('01:35', 'NUM'), ('PM...
# 1      [('The', 'DET'), ('industry', 'NOUN'), ('has',...
# 2      [('Love', 'VERB'), ('this', 'DET'), ('place', ...
# 3      [('This', 'DET'), ('problem', 'NOUN'), ('of', ...
# 4      [('Esso', 'PROPN'), ('said', 'VERB'), ('0', 'X...
# ...                                                  ...
# 52494  [('Superstition', 'NOUN'), ('has', 'VERB'), ('...
# 52495  [('You', 'PRON'), ('now', 'ADV'), ('should', '...
# 52496  [('But', 'CONJ'), ('in', 'ADP'), ('the', 'DET'...
# 52497  [('Specifically', 'ADV'), (',', 'PUNCT'), ('Je...
# 52498  [('B', 'ADJ'), ('&', 'CCONJ'), ('w', 'ADJ'), (...
#
# [52499 rows x 1 columns]

# %%
df["sen"][0]
type(df['sen'][0][1])
# Out:
# str

# %%
import ast

df["sen"] = df["sen"].apply(ast.literal_eval)
print(type(df["sen"][0]))
# Out:
# <class 'list'>

# %%
df['sen'][0]
# Out:
# [('03/01/2001', 'NUM'), ('01:35', 'NUM'), ('PM', 'NOUN')]

# %% [markdown]
# # **Pre-Processing the Dataset**

# %% [markdown]
# **Split the data into words and their respective tags for processing**

# %%
import pandas as pd
import ast

# column_name = df.columns[0]
column_name = 'sen'

pairs = []
for tup in df[column_name]:
    for pair in tup:
        pairs.append(pair)

df_expanded = pd.DataFrame(pairs, columns=["word", "tag"])

# %%
df_expanded.head()
# Out:
#          word   tag
# 0  03/01/2001   NUM
# 1       01:35   NUM
# 2          PM  NOUN
# 3         The   DET
# 4    industry  NOUN

# %% [markdown]
# **Finding unique tags and words in our dataset**

# %%
uniqueTags = df_expanded["tag"].unique()
print("Unique Tags in Dataset:", len(uniqueTags))
uniqueWords = df_expanded["word"].unique();
print("Unique Words in Dataset:", len(uniqueWords))
# Out:
# Unique Tags in Dataset: 21
# Unique Words in Dataset: 58110

# %% [markdown]
# # Estimate HMM Parameters using the training set

# %% [markdown]
# **Finding Initial Probability**

# %%
from collections import defaultdict

initial_prob = defaultdict(int)
total_sentences = len(df)

for i in df["sen"]:
    tag = i[0][1]
    initial_prob[tag] += 1

for tag in initial_prob:
    initial_prob[tag] = initial_prob[tag] / total_sentences

print("----------------------------------------Initial Probabilities:----------------------------------------")
for tag, prob in initial_prob.items():
    print(f"{tag} : {prob:}")
# Out:
# ----------------------------------------Initial Probabilities:----------------------------------------
# NUM : 0.022686146402788626
# DET : 0.19897521857559192
# VERB : 0.04920093716070782
# PROPN : 0.04114364083125393
# PRON : 0.16137450237147374
# NOUN : 0.1239833139678851
# ADP : 0.11245928493876074
# AUX : 0.006533457780148193
# . : 0.04421036591173165
# PRT : 0.023657593477971008
# CCONJ : 0.005409626850035239
# INTJ : 0.008533495876111926
# ADV : 0.08525876683365398
# SCONJ : 0.008666831749176174
# CONJ : 0.03701022876626221
# _ : 0.01055258195394198
# PUNCT : 0.009695422769957524
# X : 0.005962018324158555
# ADJ : 0.04163888835977828
# SYM : 0.0017143183679689136
# PART : 0.0013333587306424883

# %% [markdown]
# **Calculation Of Transition and Emission Probability**

# %%
tag_counts = {}
transition_counts = {}
word_counts = {}

prev_tag = None

for _, row in df_expanded.iterrows():
    word = row["word"]
    tag = row["tag"]

    if tag in tag_counts:
        tag_counts[tag] += 1
    else:
        tag_counts[tag] = 1

    if prev_tag is not None:=
        if prev_tag not in transition_counts:
            transition_counts[prev_tag] = {}
        if tag in transition_counts[prev_tag]:
            transition_counts[prev_tag][tag] += 1
        else:
            transition_counts[prev_tag][tag] = 1
    prev_tag = tag

for _, row in df_expanded.iterrows():
    word = row["word"]
    tag = row["tag"]

    if tag not in word_counts:
        word_counts[tag] = {}
    if word in word_counts[tag]:
        word_counts[tag][word] += 1
    else:
        word_counts[tag][word] = 1

# %%
print("Tag Counts:", tag_counts)
print("Transition Counts:", transition_counts)
print("Word Counts:", word_counts)
# Out:
# Tag Counts: {'NUM': 17148, 'NOUN': 240200, 'DET': 115786, 'VERB': 151833, 'ADJ': 76692, '.': 94933, 'PUNCT': 23826, 'ADP': 125188, 'CONJ': 27234, 'PROPN': 19556, 'X': 13180, 'PRON': 48875, 'ADV': 49059, 'AUX': 12771, 'INTJ': 755, 'CCONJ': 6535, 'PRT': 18688, 'PART': 7586, 'SCONJ': 3720, '_': 2668, 'SYM': 739}
# Transition Counts: {'NUM': {'NUM': 918, 'NOUN': 6198, 'VERB': 610, 'ADJ': 862, '.': 3167, 'PROPN': 196, 'AUX': 44, 'X': 652, 'ADP': 1871, 'DET': 210, 'PUNCT': 1118, 'SYM': 144, 'CONJ': 459, 'PRON': 157, 'ADV': 265, 'PRT': 70, 'PART': 60, 'CCONJ': 112, '_': 12, 'SCONJ': 15, 'INTJ': 8}, 'NOUN': {'DET': 3774, 'VERB': 33904, '.': 53525, 'PUNCT': 10009, 'ADP': 58751, 'CONJ': 12096, 'NOUN': 36310, 'PROPN': 445, 'PRT': 3421, 'NUM': 2050, 'PART': 1425, 'CCONJ': 2402, 'AUX': 2451, 'X': 3668, 'ADJ': 3169, 'PRON': 5242, 'ADV': 6438, 'SCONJ': 790, '_': 174, 'SYM': 125, 'INTJ': 31}, 'DET': {'NOUN': 70465, 'ADJ': 28003, 'PROPN': 1962, 'VERB': 6718, 'NUM': 1325, 'DET': 760, 'PUNCT': 195, 'ADP': 1145, '.': 1206, 'ADV': 2045, 'CCONJ': 14, '_': 130, 'CONJ': 63, 'PRON': 1019, 'X': 480, 'PRT': 174, 'AUX': 33, 'SYM': 37, 'INTJ': 1, 'SCONJ': 3, 'PART': 8}, 'VERB': {'VERB': 24553, 'NUM': 1642, 'DET': 25147, '
1999': 1, '2009': 10, '2019': 4, '6.40': 2, '1991': 21, '7.458': 2, '75,000': 2, '06/01/2001': 3, '03:20': 3, '47.6': 2, '46': 14, '45.3': 1, '40,000': 10, '140': 5, 'Twenty-six': 1, 'forty': 21, '700': 10, 'ninety': 6, '180': 10, '0.52': 1, '1994': 3, '0.25': 2, '190': 2, '9:30': 7, '17,000': 1, '8.5': 1, '04:37': 2, '1923': 6,  ...

# %%
transition_prob = {}
for t1 in transition_counts:
    transition_prob[t1] = {}
    for t2 in transition_counts[t1]:
        transition_prob[t1][t2] = transition_counts[t1][t2] / tag_counts[t1]

# %%
print("\n---------------------------------------- Transition Probabilities (Tag → Next Tag) -------------------------------------------")
for t1 in transition_prob:
    for t2 in transition_prob[t1]:
        print(f"{t1} → {t2} : {transition_prob[t1][t2]}")
# Out:
# ---------------------------------------- Transition Probabilities (Tag → Next Tag) -------------------------------------------
# NUM → NUM : 0.053533939818054585
# NUM → NOUN : 0.3614415675297411
# NUM → VERB : 0.035572661534872874
# NUM → ADJ : 0.05026825285747609
# NUM → . : 0.18468626078843015
# NUM → PROPN : 0.011429904362024726
# NUM → AUX : 0.0025658968975973873
# NUM → X : 0.03802192675530674
# NUM → ADP : 0.10910893398647073
# NUM → DET : 0.01224632610216935
# NUM → PUNCT : 0.06519710753440634
# NUM → SYM : 0.008397480755773267
# NUM → CONJ : 0.026766969909027293
# NUM → PRON : 0.009155586657336132
# NUM → ADV : 0.015453697224166084
# NUM → PRT : 0.004082108700723117
# NUM → PART : 0.0034989503149055285
# NUM → CCONJ : 0.006531373921156987
# NUM → _ : 0.0006997900629811056
# NUM → SCONJ : 0.0008747375787263821
# NUM → INTJ : 0.00046652670865407047
# NOUN → DET : 0.015711906744379684
# NOUN → VERB : 0.14114904246461282
# NOUN → . : 0.22283513738551208
# NOUN → PUNCT : 0.04166944213155704
# NOUN → ADP : 0.24459200666111575
# NOUN → CONJ : 0.05035803497085762
# NOUN → NOUN : 0.15116569525395504
# NOUN → PROPN : 0.0018526228143213989
# NOUN → PRT : 0.014242298084929226
# NOUN → NUM : 0.008534554537885096
# NOUN → PART : 0.00593255620316403
# NOUN → CCONJ : 0.01
# NOUN → AUX : 0.010203996669442132
# NOUN → X : 0.015270607826810991
# NOUN → ADJ : 0.013193172356369692
# NOUN → PRON : 0.02182348043297252
# NOUN → ADV : 0.026802664446294755
# NOUN → SCONJ : 0.003288925895087427
# NOUN → _ : 0.0007243963363863448
# NOUN → SYM : 0.0005203996669442131
# NOUN → INTJ : 0.00012905911740216487
# DET → NOUN : 0.6085796210249944
# DET → ADJ : 0.2418513464494844
# DET → PROPN : 0.01694505380615964
# DET → VERB : 0.05802083153403693
# DET → NUM : 0.011443525123935537
# DET → DET : 0.006563833278634723
# DET → PUNCT : 0.001684141433333909
# DET → ADP : 0.009888933031627313
# DET → . : 0.010415767018465099
# DET → ADV : 0.01766189349316843
# DET → CCONJ : 0.00012091271829063962
# DET → _ : 0.0011227609555559395
# DET → CONJ : 0.0005441072323078783
# DET → PRON : 0.008800718567011557
# DET → X : 0.0041455789128219305
# DET → PRT : 0.0015027723558979497
# DET → AUX : 0.0002850085502565077
# DET → SYM : 0.00031955504119669044
# DET → INTJ : 8.636622735045688e-06
# DET → SCONJ : 2.5909868205137065e-05
# DET → PART : 6.90929818803655e-05
# VERB → VERB : 0.16171056357972247
# VERB → NUM : 0.010814513313969954
# VERB → DET : 0.16562275658124387
# VERB → ADP : 0.17207063023189953
# VERB → X : 0.014693775397970139
# VERB → NOUN : 0.09780482503803521
# VERB → ADV : 0.09740965402778053
# VERB → PRON : 0.06363570501801322
# VERB → PRT : 0.04881020594995818
# VERB → . : 0.059611546896919644
# VERB → ADJ : 0.0580901385074391
# VERB → CONJ : 0.01186830267464912
# VERB → PUNCT : 0.01157851060046235
# VERB → SCONJ : 0.005756324382709951
# VERB → PART : 0.01064327254285959
# VERB → PROPN : 0.005143809316815185
# VERB → CCONJ : 0.0024237155295620846
# VERB → AUX : 0.0009813413421324744
# VERB → _ : 0.000869376222560313
# VERB → SYM : 0.0002832058906825262
# VERB → INTJ : 0.00017782695461460946
# ADJ → NOUN : 0.637706670839201
# ADJ → X : 0.005372137902258384
# ADJ → ADJ : 0.05782871746727168
# ADJ → . : 0.07038543785531737
# ADJ → DET : 0.005593803786574871
# ADJ → ADV : 0.009935847285244876
# ADJ → PUNCT : 0.023731288791529755
# ADJ → CONJ : 0.029455484274761384
# ADJ → ADP : 0.08441558441558442
# ADJ → CCONJ : 0.007393209200438116
# ADJ → SCONJ : 0.003963907578365409
# ADJ → SYM : 0.00032597924164189226
# ADJ → VERB : 0.015946904501121368
# ADJ → PRT : 0.014499556668231366
# ADJ → NUM : 0.008071246023053253
# ADJ → PROPN : 0.013234757210660825
# ADJ → AUX : 0.0006910759922808115
# ADJ → PRON : 0.00453763104365514
# ADJ → PART : 0.006154488082198925
# ADJ → _ : 0.0007041151619464872
# ADJ → INTJ : 5.215667866270276e-05
# . → VERB : 0.0969525876144228
# . → PROPN : 0.015189660076053638
# . → NOUN : 0.1351900814258477
# . → . : 0.11250039501543194
# . → DET : 0.1471985505567084
# . → ADP : 0.1122265176492895
# . → AUX : 0.0026229024680564186
# . → PRON : 0.10229319625420033
# . → ADJ : 0.04705423825224105
# . → PRT : 0.023732527150727354
# . → CCONJ : 0.002159417694584602
# . → ADV : 0.07623271149126226
# . → CONJ : 0.08493358473871046
# . → NUM : 0.022679152665564136
# . → _ : 0.003939620574510444
# . → PUNCT : 0.003792148146587593
# . → X : 0.0036341419738131105
# . → INTJ : 0.0032338596694510865
# . → SCONJ : 0.003275994648857615
# . → SYM : 0.0006636259256528288
# . → PART : 0.0004950860080267136
# PUNCT → DET : 0.12616469403173003
# PUNCT → CCONJ : 0.05854948375723999
# PUNCT → PUNCT : 0.050239234449760764
# PUNCT → . : 0.02119533282968186
# PUNCT → PROPN : 0.07823386216738017
# PUNCT → PRON : 0.141735918744229
# PUNCT → INTJ : 0.009905145639217662
# PUNCT → CONJ : 0.01695626626374549
# PUNCT → NOUN : 0.12616469403173003
# PUNCT → ADV : 0.0727356669184924
# PUNCT → _ : 0.01578107949299085
# INTJ → ADJ : 0.003973509933774834
# INTJ → PART : 0.0026490066225165563
# INTJ → NUM : 0.011920529801324504
# INTJ → SYM : 0.0013245033112582781
# INTJ → X : 0.0026490066225165563
# CCONJ → VERB : 0.17352716143840857
# CCONJ → ADP : 0.028768171384850803
# CCONJ → NOUN : 0.14567712318286152
# CCONJ → ADV : 0.08186687069625095
# CCONJ → PROPN : 0.07865340474368783
# CCONJ → ADJ : 0.09089517980107116
# CCONJ → _ : 0.025095638867635807
# CCONJ → AUX : 0.04468247895944912
# CCONJ → DET : 0.09854628921193573
# CCONJ → SCONJ : 0.016679418515684774
# CCONJ → PRON : 0.16694720734506505
# CCONJ → PART : 0.015302218821729151
# CCONJ → PUNCT : 0.01224177505738332
# CCONJ → NUM : 0.013618974751338945
# CCONJ → INTJ : 0.0022953328232593728
# CCONJ → SYM : 0.004896710022953328
# CCONJ → CCONJ : 0.0001530221882172915
# CCONJ → X : 0.0001530221882172915
# PRT → VERB : 0.6545911815068494
# PRT → . : 0.062018407534246575
# PRT → NUM : 0.005779109589041096
# PRT → CONJ : 0.009899400684931507
# PRT → ADP : 0.08657962328767123
# PRT → NOUN : 0.03751070205479452
# PRT → DET : 0.08171018835616438
# PRT → ADJ : 0.01792594178082192
# PRT → ADV : 0.028788527397260275
# PRT → PRT : 0.009417808219178082
# PRT → PRON : 0.005618578767123288
# PRT → _ : 5.351027397260274e-05
# PRT → X : 0.00010702054794520547
# PART → VERB : 0.6269443712101239
# PART → NOUN : 0.10282098602689164
# PART → X : 0.009886633271816504
# PART → DET : 0.03625098866332718
# PART → AUX : 0.05180595834431848
# PART → ADJ : 0.052333245452148694
# PART → ADP : 0.008041128394410757
# PART → PART : 0.004218296862641709
# PART → ADV : 0.03480094911679409
# PART → PUNCT : 0.01595043501186396
# PART → PRON : 0.010677563933561824
# PART → NUM : 0.014104930134458212
# PART → CCONJ : 0.0021091484313208544
# PART → PROPN : 0.026627998945425783
# PART → SCONJ : 0.001713683100448194
# PART → SYM : 0.00039546533087266017
# PART → _ : 0.000659108884787767
# PART → CONJ : 0.0005272871078302136
# PART → INTJ : 0.0001318217769575534
# SCONJ → PRON : 0.4505376344086022
# SCONJ → DET : 0.135752688172043
# SCONJ → VERB : 0.16129032258064516
# SCONJ → ADP : 0.013440860215053764
# SCONJ → PUNCT : 0.008870967741935484
# SCONJ → _ : 0.032526881720430105
# SCONJ → NOUN : 0.034408602150537634
# SCONJ → PROPN : 0.05161290322580645
# SCONJ → ADV : 0.027419354838709678
# SCONJ → ADJ : 0.026344086021505377
# SCONJ → SCONJ : 0.023655913978494623
# SCONJ → AUX : 0.012634408602150538
# SCONJ → CCONJ : 0.003763440860215054
# SCONJ → INTJ : 0.0016129032258064516
# SCONJ → PART : 0.008870967741935484
# SCONJ → NUM : 0.006989247311827957
# SCONJ → X : 0.00026881720430107527
# _ → AUX : 0.297976011994003
# _ → PRON : 0.4186656671664168
# _ → PROPN : 0.17091454272863568
# _ → NOUN : 0.08545727136431784
# _ → VERB : 0.015742128935532233
# _ → ADJ : 0.0018740629685157421
# _ → ADV : 0.006746626686656672
# _ → ADP : 0.0011244377811094452
# _ → NUM : 0.0007496251874062968
# _ → X : 0.0003748125937031484
# _ → DET : 0.0003748125937031484
# SYM → NUM : 0.5006765899864682
# SYM → SYM : 0.018944519621109608
# SYM → PRON : 0.036535859269282815
# SYM → PUNCT : 0.04059539918809202
# SYM → DET : 0.04059539918809202
# SYM → AUX : 0.005412719891745603
# SYM → VERB : 0.029769959404600813
# SYM → NOUN : 0.12719891745602166
# SYM → CCONJ : 0.04330175913396482
# SYM → PROPN : 0.046008119079837616
# SYM → ADP : 0.02706359945872801
# SYM → ADJ : 0.037889039242219216
# SYM → ADV : 0.02029769959404601
# SYM → INTJ : 0.0040595399188092015
# SYM → PRT : 0.0040595399188092015
# SYM → CONJ : 0.006765899864682003
# SYM → . : 0.006765899864682003
# SYM → SCONJ : 0.0027063599458728013
# SYM → X : 0.0013531799729364006

# %%
emission_prob = {}
for tag in word_counts:
    emission_prob[tag] = {}
    for word in word_counts[tag]:
        emission_prob[tag][word] = word_counts[tag][word] / tag_counts[tag]

# %%
print("\n----------------------------------------- Emission Probabilities (Tag → Word) ------------------------------------------------")
for tag in emission_prob:
    print(f"\n{tag}:")
    for word, prob in sorted(emission_prob[tag].items(), key=lambda x: -x[1])[:5]:  # Show top 10 words
        print(f"  {word}: {prob}")
# Out:
# ----------------------------------------- Emission Probabilities (Tag → Word) ------------------------------------------------
#
# NUM:
#   one: 0.11913925822253324
#   two: 0.06601352927455097
#   1: 0.03318171215302076
#   2: 0.03084907860975041
#   three: 0.02775833916491719
#
# NOUN:
#   time: 0.006065778517901748
#   years: 0.003671940049958368
#   people: 0.003459616985845129
#   Af: 0.0034429641965029144
#   year: 0.0032639467110741048
#
# DET:
#   the: 0.4709982208557166
#   a: 0.16907052666125438
#   The: 0.05590485896395073
#   his: 0.03307826507522498
#   this: 0.03078092342770283
#
# VERB:
#   is: 0.05399353236779883
#   was: 0.04057089038614794
#   be: 0.031640025554392
#   have: 0.02413177635955293
#   are: 0.024079086891518973
#
# ADJ:
#   other: 0.01927189276586867
#   new: 0.01418661659625515
#   more: 0.011996036092421634
#   many: 0.011057215876492985
#   such: 0.010744275804516768
#
# .:
#   ,: 0.4092359874859111
#   .: 0.33306647846375864
#   ``: 0.05227897569865063
#   '': 0.05188922713914024
#   ;: 0.04116587488017865
#
# PUNCT:
#   .: 0.36716192394862757
#   ,: 0.2907328128934777
#   ": 0.05473012675228742
#   -: 0.05422647527910686
#   ?: 0.03676655754218081
#
# ADP:
#   of: 0.24746780841614213
#   in: 0.1377128798287376
#   to: 0.07465571780042815
#   for: 0.06715499888168196
#   with: 0.049118126337987664
#
# CONJ:
#   and: 0.7300066093853271
#   or: 0.11518689872952927
#   but: 0.07042667254167585
#   But: 0.03491958581185283
#   And: 0.021370345891165456
#
# PROPN:
#   Mr.: 0.014778073225608509
#   Bush: 0.011198609122519942
#   U.S.: 0.009102065862139496
#   US: 0.00833503784004909
#   New: 0.005420331356105543
#
# X:
#   ,: 0.23937784522003036
#   .: 0.18505311077389985
#   *-1: 0.0535660091047041
#   0: 0.052579666160849775
#   *: 0.04954476479514416
#
# PRON:
#   it: 0.12423529411764705
#   I: 0.11562148337595908
#   he: 0.09162148337595907
#   you: 0.06938107416879795
#   they: 0.05651150895140665
#
# ADV:
#   not: 0.06396379869137162
#   when: 0.02978046841558124
#   so: 0.026498705640147578
#   only: 0.02246274893495587
#   also: 0.022340447216616727
#
# AUX:
#   is: 0.16568788661811917
#   was: 0.09083078850520711
#   be: 0.08440999138673558
#   are: 0.07877221830710203
#   will: 0.06256362070315559
#
# INTJ:
#   Please: 0.19735099337748344
#   please: 0.1509933774834437
#   Yes: 0.05033112582781457
#   no: 0.045033112582781455
#   Well: 0.04370860927152318
#
# CCONJ:
#   and: 0.7210405508798776
#   or: 0.10390206579954094
#   but: 0.09074215761285387
#   &: 0.018515684774292274
#   But: 0.017750573833205815
#
# PRT:
#   to: 0.533818493150685
#   all: 0.0896297089041096
#   out: 0.05260059931506849
#   up: 0.052065496575342464
#   there: 0.05115582191780822
#
# PART:
#   to: 0.5999209069338255
#   's: 0.13485367782757712
#   not: 0.12140785657790668
#   n't: 0.08779330345373056
#   s: 0.010150276825731611
#
# SCONJ:
#   that: 0.2532258064516129
#   if: 0.12258064516129032
#   as: 0.07903225806451612
#   If: 0.07123655913978495
#   because: 0.03978494623655914
#
# _:
#   don't: 0.09220389805097451
#   I'm: 0.07383808095952024
#   it's: 0.03860569715142429
#   It's: 0.030359820089955022
#   I've: 0.029610194902548726
#
# SYM:
#   $: 0.3112313937753721
#   /: 0.19621109607577808
#   -: 0.12990527740189445
#   :): 0.06765899864682003
#   #: 0.058186738836265225

# %%
# print("Sample Transition Probabilities:", list(transition_prob.items())[:5])
# print("Sample Emission Probabilities:", list(emission_prob.items())[:5])

# %%
print("Transition Probability Example:", transition_prob.get("NOUN", "Not Available"))
print("Emission Probability Example:", emission_prob.get("NOUN", "Not Available"))
# Out:
# Transition Probability Example: {'DET': 0.015711906744379684, 'VERB': 0.14114904246461282, '.': 0.22283513738551208, 'PUNCT': 0.04166944213155704, 'ADP': 0.24459200666111575, 'CONJ': 0.05035803497085762, 'NOUN': 0.15116569525395504, 'PROPN': 0.0018526228143213989, 'PRT': 0.014242298084929226, 'NUM': 0.008534554537885096, 'PART': 0.00593255620316403, 'CCONJ': 0.01, 'AUX': 0.010203996669442132, 'X': 0.015270607826810991, 'ADJ': 0.013193172356369692, 'PRON': 0.02182348043297252, 'ADV': 0.026802664446294755, 'SCONJ': 0.003288925895087427, '_': 0.0007243963363863448, 'SYM': 0.0005203996669442131, 'INTJ': 0.00012905911740216487}
# Emission Probability Example: {'PM': 0.00046627810158201497, 'industry': 0.0007160699417152373, 'year': 0.0032639467110741048, 'place': 0.0022356369691923397, 'problem': 0.0013863447127393839, 'balance': 0.0003372189841798501, 'numbers': 0.0005120732722731058, 'generalists': 8.32639467110741e-06, 'specialists': 9.159034138218151e-05, 'network': 0.00013322231473771856, 'basis': 0.0007243963363863448, 'field': 0.0007826810990840966, 'production': 0.0004870940882597835, 'breath': 0.00012905911740216487, 'Glendora': 4.1631973355537055e-05, 'side': 0.0010
# %% [markdown]
# # Viterbi Algorithm Implementation

# %%
def initialize_viterbi(sentence, states, initial_prob, emission_prob):
    Viterbi = []
    Backpointer = []

    for i in range(len(states)):
        state = states[i]
        if state in initial_prob:
            init_prob = initial_prob[state]
        else:
            init_prob = 1e-6

        if state in emission_prob and sentence[0] in emission_prob[state]:
            emit_prob = emission_prob[state][sentence[0]]
        else:
            emit_prob = 1e-6

        Viterbi.append([init_prob * emit_prob])
        Backpointer.append([0])

    return Viterbi, Backpointer

def fill_viterbi(sentence, states, Viterbi, Backpointer, transition_prob, emission_prob):
    for t in range(1, len(sentence)):
        for s in range(len(states)):
            max_prob = 0
            best_prev_state = 0
            for k in range(len(states)):
                if states[k] in transition_prob and states[s] in transition_prob[states[k]]:
                    trans_prob = transition_prob[states[k]][states[s]]
                else:
                    trans_prob = 1e-6

                if states[s] in emission_prob and sentence[t] in emission_prob[states[s]]:
                    emit_prob = emission_prob[states[s]][sentence[t]]
                else:
                    emit_prob = 1e-6

                prob = Viterbi[k][t - 1] * trans_prob * emit_prob
                if prob > max_prob:
                    max_prob = prob
                    best_prev_state = k

            Viterbi[s].append(max_prob)
            Backpointer[s].append(best_prev_state)

    return Viterbi, Backpointer

def backtrack_viterbi(Viterbi, Backpointer, states):
    T = len(Viterbi[0])
    max_value = 0
    last_state = 0
    for i in range(len(Viterbi)):
        if Viterbi[i][T - 1] > max_value:
            max_value = Viterbi[i][T - 1]
            last_state = i

    best_sequence = [last_state]

    for t in range(T - 1, 0, -1):
        last_state = Backpointer[last_state][t]
        best_sequence.append(last_state)

    best_sequence.reverse()
    predicted_tags = []
    for i in best_sequence:
        predicted_tags.append(states[i])

    return predicted_tags

def viterbi_algorithm(sentence, states, initial_prob, transition_prob, emission_prob):
    Viterbi, Backpointer = initialize_viterbi(sentence, states, initial_prob, emission_prob)
    Viterbi, Backpointer = fill_viterbi(sentence, states, Viterbi, Backpointer, transition_prob, emission_prob)
    return backtrack_viterbi(Viterbi, Backpointer, states)

# %% [markdown]
# # Model Evaluation

# %%
import pandas as pd

file_path = "https://raw.githubusercontent.com/girishofficial/Viterbi_algorithm/refs/heads/main/TEST.csv"
df_test = pd.read_csv(file_path,names=["sen"])

print(df_test.head())
# Out:
#                                                  sen
# 0                                  [('DF', 'PROPN')]
# 1  [('03/01/2001', 'NUM'), ('01:35', 'NUM'), ('PM...
# 2  [('The', 'DET'), ('industry', 'NOUN'), ('has',...
# 3  [('Love', 'VERB'), ('this', 'DET'), ('place', ...
# 4  [('This', 'DET'), ('problem', 'NOUN'), ('of', ...

# %%
df_test["sen"] = df_test["sen"].apply(ast.literal_eval)
print(type(df_test["sen"][0]))
# Out:
# <class 'list'>

# %%
word_sequences = []

for sentence in df_test["sen"]:
    words = []
    for word, tag in sentence:
        words.append(word)
    word_sequences.append(words)
print(word_sequences[3])
# Out:
# ['Love', 'this', 'place', '!!']

# %%
states = df_expanded["tag"].unique()

predicted_tags_list = []

for words in word_sequences:
    predicted_tags = viterbi_algorithm(words, states, initial_prob, transition_prob, emission_prob)
    predicted_tags_list.append(predicted_tags)

# %%
true_tags_list = []

for sentence in df_test["sen"]:
    tags_only = []
    for word, tag in sentence:
        tags_only.append(tag)
    true_tags_list.append(tags_only)

# %%
total_words = 0
correct_predictions = 0

for i in range(len(true_tags_list)):
    for j in range(len(true_tags_list[i])):
        total_words += 1
        if true_tags_list[i][j] == predicted_tags_list[i][j]:
            correct_predictions += 1

accuracy = (correct_predictions / total_words) * 100
print(f"Viterbi Algorithm Accuracy: {accuracy:.2f}%")
# Out:
# Viterbi Algorithm Accuracy: 88.99%

# %% [markdown]
# ## confusion matrix on test data

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

all_tags = sorted(set(tag for tags in true_tags_list for tag in tags))

conf_matrix = confusion_matrix(
    [tag for tags in true_tags_list for tag in tags],
    [tag for tags in predicted_tags_list for tag in tags],
    labels=all_tags
)

plt.figure(figsize=(20, 5))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=all_tags, yticklabels=all_tags)

plt.xlabel("Predicted Labels")
plt.ylabel("Actual Labels")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # **Effect of Lemmatization**

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_word(word):
    return lemmatizer.lemmatize(word)

# %% [markdown]
# Lemmatization on train data

# %%
df_expanded["word"] = df_expanded["word"].apply(lemmatize_word)

# %% [markdown]
# Lemmatization on test data

# %%
word_sequences = [[lemmatizer.lemmatize(word) for word in sentence] for sentence in word_sequences]

# %% [markdown]
# # **Viterbi algorithm on lemmatized data**

# %%
states = df_expanded["tag"].unique()
predicted_tags_list = []

for words in word_sequences:
    predicted_tags = viterbi_algorithm(words, states, initial_prob, transition_prob, emission_prob)
    predicted_tags_list.append(predicted_tags)  # Store predicted tags

# %%
predicted_tags_list
# Out:
# [['PROPN'],
#  ['NUM', 'NUM', 'NOUN'],
#  ['DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', '.'],
#  ['VERB', 'DET', 'NOUN', 'PUNCT'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PROPN', 'VERB', 'X', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'NOUN', '.'],
#  ['PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.'],
#  ['NOUN', '.', '.'],
#  ['DET',
#   'NOUN',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['AUX',
#   'PRON',
#   'INTJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  ['.', 'VERB', 'PRON', 'VERB', 'ADP', 'NOUN', '.', '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADV',
#   'DET',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'VERB',
#   '.'],
#  ['.', 'ADV', '.', '.', '.'],
#  ['AUX',
#   'ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN', 'VERB', 'CONJ', 'NOUN'],
#  ['PRON',
#   'AUX',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   '.',
#   'VERB',
#   'PRT',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'ADP',
#   'ADJ',
#   'PUNCT',
#   'PROPN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON', 'PRT', 'VERB', 'ADP', 'PROPN', 'PROPN', 'PROPN', 'PUNCT'],
#  ['INTJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADJ',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['PROPN', 'PROPN', 'X'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'VERB',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'ADV',
#   '.',
#   'DET',
#   'PRON',
#   'VERB',
#   'NUM',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'PRON',
#   'VERB',
#   'PRON',
#   'CONJ',
#   'DET',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NUM',
#   '.',
#   'ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'CCONJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'X',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['SCONJ',
#   'PRON',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'PRON',
#   'AUX',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PROPN', 'VERB', 'DET', 'NOUN', 'VERB', 'PRT', 'VERB', 'NOUN', '.'],
#  ['NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PROPN',
#   'CCONJ',
#   'PROPN',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADV',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   '.'],
#  ['PROPN', 'PROPN', 'PROPN', 'PROPN'],
#  ['.',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.'],
#  ['NUM'],
#  ['DET',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   '.',
#   'VERB',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'AUX',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['_',
#   'AUX',
#   'PART',
#   'VERB',
#   'ADV',
#   'DET',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.'],
#  ['INTJ', 'VERB', '.'],
#  ['ADV',
#   'PRON',
#   'ADV',
#   'VERB',
#   'VERB',
#   'PRON',
#   '_',
#   'PRON',
#   'AUX',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'PROPN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NOUN', 'ADP', 'NUM', 'VERB', 'DET', 'NOUN', '.'],
#  ['PRON',
#   'CCONJ',
#   'PROPN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADV',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['NOUN', '.'],
#  ['PRT',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   'PROPN',
#   'PROPN',
#   'CCONJ',
#   'PROPN',
#   'PROPN',
#   'PUNCT'],
#  ['ADV',
#   '.',
#   'PRT',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PROPN'],
#  ['DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'VERB',
#   '.'],
#  ['PUNCT',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CONJ', 'PRON', 'VERB', 'CONJ', 'DET', 'NOUN', 'NOUN', '.', 'ADV', '.'],
#  ['PRT', 'DET', 'ADJ', 'CONJ', 'NOUN', 'NOUN'],
#  ['ADV',
#   '.',
#   'ADV',
#   '.',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'DET',
#   'PRT',
#   'CONJ',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'INTJ',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['.', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', '.', '.'],
#  ['.',
#   'PRON',
#   'AUX',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['.',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'X',
#   'PART',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PART',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'PRT',
#   '.',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'PRT',
#   'VERB',
#   'PRT',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'ADV',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   '.'],
#  ['ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['ADP', 'NUM', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'PRT', '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   '.',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'VERB',
#   'PRON',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'X',
#   'X',
#   'PART',
#   'VERB',
#   'VERB',
#   'X',
#   'X',
#   'X',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'CCONJ',
#   '_',
#   'PRON',
#   'AUX',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['PROPN',
#   'PROPN',
#   'PROPN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'PROPN',
#   'NUM',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'SYM',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'X',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'X',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'SYM',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'X',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'X',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PART',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'PRT',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PROPN',
#   'CCONJ',
#   'PROPN',
#   'PART',
#   'VERB',
#   'ADP',
#   'CONJ',
#   'VERB',
#   '.'],
#  ['_',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'DET',
#   'NOUN'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADV',
#   '.',
#   'ADV',
#   '.',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['PRON',
#   '_',
#   'AUX',
#   'PART',
#   'DET',
#   'PROPN',
#   'CCONJ',
#   'PROPN',
#   'PUNCT',
#   'PRON',
#   'PRON',
#   'AUX',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'PART',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.',
#   'VERB',
#   'PRON',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADV',
#   '.',
#   'ADP',
#   'ADV',
#   'PRON',
#   'VERB',
#   'PRON',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PROPN'],
#  ['PROPN'],
#  ['CONJ',
#   'DET',
#   '.',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'PROPN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'PROPN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PROPN',
#   'AUX',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   '.',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NUM',
#   'DET',
#   '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '_',
#   'PRON',
#   'AUX',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'CONJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   '.',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'PUNCT',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'PRON',
#   'ADV',
#   'PRT',
#   'VERB',
#   'NUM',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['_',
#   'PROPN',
#   'PART',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'PRT',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   '.',
#   '.'],
#  ['PROPN', 'PROPN', 'PUNCT', 'ADJ', '.'],
#  ['PRON', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'PRT', '.'],
#  ['PRON',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PROPN',
#   'CCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['ADV',
#   'ADV',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN', 'NOUN', 'VERB'],
#  ['PRON',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '_',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'PRON',
#   'AUX',
#   'ADV',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PROPN', 'PUNCT'],
#  ['VERB', 'PRON', 'SCONJ', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', '.'],
#  ['INTJ', 'PUNCT'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'PRON',
#   '.'],
#  ['PROPN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   '.',
#   'DET',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADJ',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   '.',
#   'ADP',
#   'ADJ',
#   '.',
#   'VERB',
#   'DET',
#   'PROPN',
#   'VERB',
#   '.'],
#  ['PROPN', 'PROPN', 'PROPN', 'PUNCT', 'NUM', 'PUNCT', 'PROPN', 'PROPN'],
#  ['DET',
#   'NOUN',
#   'PRON',
#   'CONJ',
#   'DET',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   'DET',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NUM',
#   '.'],
#  ['DET',
#   'ADJ',
#   'SYM',
#   'NUM',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PROPN',
#   'ADP',
#   'DET',
#   '_',
#   'PROPN',
#   'PART',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'NUM',
#   'SYM',
#   'NUM',
#   'SYM',
#   'SYM'],
#  ['PRON',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'VERB',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'NUM',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   '.',
#   '.',
#   'ADV',
#   'SCONJ',
#   '_',
#   'ADJ',
#   '.',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'X',
#   'X',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['INTJ', 'VERB', 'DET', 'NOUN', 'ADP', 'ADJ', 'ADV', '.'],
#  ['ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'PRT',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['.', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'PRON', '.', 'ADP', 'NOUN', '.', 'PRT', 'ADV', 'ADJ', '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'PROPN',
#   'PUNCT',
#   'PROPN',
#   'NUM',
#   'SYM',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PROPN'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN', '.', 'NOUN', '.', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   '.',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PART',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   '.',
#   '.'],
#  ['DET', 'NOUN', 'VERB', 'ADP', 'ADJ', 'NOUN', '.'],
#  ['DET',
#   'NUM',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'DET',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRT',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PROPN',
#   'PART',
#   'VERB',
#   'ADV',
#   '.',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PRT',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADV',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'NOUN', 'NOUN', 'VERB', 'PRT', '.'],
#  ['NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   '.',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRON',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADV',
#   'DET',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PRON',
#   'VERB',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'PROPN',
#   'PROPN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PROPN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADV',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADJ',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'PROPN',
#   'PART',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   '.'],
#  ['ADP',
#   'ADV',
#   'PRON',
#   'PRT',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'AUX',
#   'ADV',
#   'ADV',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   'X',
#   'X',
#   'CONJ',
#   'NOUN',
#   'ADJ',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADJ',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON', 'AUX', 'PART', 'VERB', 'SCONJ', 'PRON', 'AUX', 'ADJ', '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET', 'ADV', 'VERB', 'ADJ', 'ADP', 'ADJ', 'NOUN', 'VERB', 'VERB', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'ADP',
#   'PRON',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET', 'NOUN', 'VERB', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'PART',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'X',
#   'PROPN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.',
#   'PROPN',
#   'NUM',
#   '.',
#   'NUM',
#   '.',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADV',
#   'ADV',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   '.',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'NOUN',
#   '_',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT'],
#  ['X',
#   'X',
#   'X',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   '.'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'ADV',
#   '.',
#   'PRT',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PROPN'],
#  ['PROPN', 'PUNCT'],
#  ['ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'NUM',
#   '.',
#   'NUM',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PUNCT',
#   'PROPN',
#   'X',
#   'X',
#   'CONJ',
#   'X',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'X',
#   'CONJ',
#   'X',
#   'X',
#   'X',
#   'X',
#   'PUNCT'],
#  ['PRON',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PUNCT'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'PROPN',
#   'PUNCT'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'PROPN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   '_',
#   'PROPN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PROPN',
#   'PART',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['NOUN', 'VERB', 'ADJ', 'ADP', 'PROPN', 'CCONJ', 'PROPN', 'PUNCT'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRT',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN', 'ADP', 'DET', 'ADJ', 'NOUN'],
#  ['SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'VERB',
#   'DET',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADV',
#   'VERB',
#   'PRT',
#   '.',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   '.'],
#  ['NUM', 'NUM', 'NOUN'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   '_',
#   'AUX',
#   'PART',
#   'VERB',
#   'DET',
#   'PRON',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PROPN', 'PART', 'NOUN'],
#  ['DET', 'NOUN', 'CONJ', 'ADJ', 'VERB', 'ADJ', '.'],
#  ['ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRT',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   'X',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET', 'ADJ', 'NOUN', 'AUX', 'PART', 'VERB', 'ADP', 'NOUN', '.'],
#  ['NOUN',
#   'ADV',
#   'NOUN',
#   '.',
#   'ADP',
#   'VERB',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.',
#   'PRON',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADV',
#   'ADP',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['VERB', 'PRON', 'VERB', '.'],
#  ['.', 'NOUN', 'NOUN', '.', '.', '.'],
#  ['ADV',
#   '.',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADV',
#   'CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['.',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'CONJ', 'VERB', 'ADP', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'NOUN',
#   'X',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   '.'],
#  ['NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['.',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'PRON',
#   'VERB',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'PRON',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADV',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.',
#   'DET',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'PROPN',
#   'PUNCT',
#   'PROPN',
#   'CCONJ',
#   'PROPN',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PROPN',
#   'PROPN',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'PRT',
#   'VERB',
#   'PROPN',
#   'PUNCT'],
#  ['_', 'PRON', 'AUX', 'PART', 'VERB', 'PRON', 'ADV', 'ADP', '.'],
#  ['CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.'],
#  ['CONJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'AUX',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PROPN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON', 'PRON', 'PRT', 'DET', 'NOUN', 'PRT', 'DET', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'PROPN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   '.'],
#  ['DET', 'ADJ', 'NOUN', '.', 'ADV', 'ADV', 'VERB', '.', 'VERB', 'NOUN', '.'],
#  ['.', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.'],
#  ['ADV', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'ADV',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['NOUN', 'VERB', 'ADJ', 'NOUN', 'NOUN', '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'PUNCT',
#   'PROPN',
#   'X',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN', 'ADP', 'NOUN'],
#  ['PRON',
#   'VERB',
#   '.',
#   'DET',
#   'PRON',
#   'VERB',
#   '.',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   '.',
#   '.'],
#  ['DET',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'VERB',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'PRT',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'DET',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADV',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PROPN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['.',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PROPN',
#   'NOUN',
#   'PART',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['.',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
# ...
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PROPN',
#   'PUNCT'],
#  ['VERB', 'DET', 'VERB', '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'PROPN',
#   'PROPN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   '.',
#   'ADV',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PROPN',
#   'NUM',
#   '.'],
#  ['ADV',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRT',
#   'ADP',
#   'ADJ',
#   'CONJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'CCONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'ADV',
#   '_',
#   'AUX',
#   'PRON',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'VERB', 'ADJ', '.'],
#  ['VERB',
#   'PRT',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'PART',
#   'ADJ',
#   '.'],
#  ['CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'NUM',
#   '.',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NUM',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'PRT',
#   'ADP',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['AUX',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['DET', 'VERB', 'VERB', 'ADV', 'ADV', '.'],
#  ['INTJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'DET',
#   'ADV',
#   'DET',
#   'ADJ',
#   '.'],
#  ['CONJ',
#   'ADV',
#   'PRON',
#   'AUX',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'ADV',
#   '.',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PROPN', 'PUNCT', 'PROPN', 'NUM', 'PUNCT', 'PROPN', 'PUNCT', 'PUNCT'],
#  ['PRON', 'AUX', 'PART', 'VERB', 'DET', 'NOUN', 'VERB'],
#  ['ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'X',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADV', 'VERB', 'PRON', 'VERB', 'PRT', 'VERB', 'NUM', 'ADV', 'ADV', '.', '.'],
#  ['NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.'],
#  ['NOUN', '.', 'ADV', 'NOUN', '.', 'VERB', 'ADV', 'ADJ', 'ADP', 'NOUN', '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'PRON',
#   'NOUN',
#   'X',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'SYM',
#   'NUM',
#   'NUM',
#   'CCONJ',
#   'SYM',
#   'NUM',
#   'NUM',
#   'X',
#   'X',
#   'ADV',
#   'DET',
#   'PROPN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'PRT',
#   'VERB',
#   '.'],
#  ['NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NUM', 'VERB', 'ADP', 'NOUN'],
#  ['ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'PRON',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'NUM',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'AUX',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   '.',
#   'VERB',
#   '.',
#   '.',
#   '.',
#   'ADJ',
#   '.',
#   '.',
#   'ADJ',
#   '.',
#   '.',
#   'CONJ',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.',
#   'ADV',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['.', 'PRT', 'DET', 'NOUN', '.', '.', '.'],
#  ['DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'VERB',
#   'ADV',
#   'NUM',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET', 'PROPN', 'PROPN', 'PUNCT'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'PROPN',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['PROPN', 'PROPN', 'X'],
#  ['PRON', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'DET',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRT',
#   'PRT',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', '.'],
#  ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'ADV', '.', '.', '.'],
#  ['SCONJ',
#   'PRON',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'PRON',
#   'VERB',
#   'ADV',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   'ADV',
#   'ADV',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'X',
#   'PROPN',
#   'PUNCT'],
#  ['PRON', 'VERB', 'DET', 'NOUN', 'PRT', '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRT',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   'PUNCT',
#   'PROPN',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NUM',
#   'SYM',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'PRON',
#   'ADP',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'ADP',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   '.',
#   '.',
#   'PRT',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   '.',
#   'ADJ',
#   '.',
#   'ADJ',
#   '.',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRT',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'PRT',
#   'ADV',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'NUM',
#   'ADP',
#   'PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['.',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'PRON',
#   'PRT',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'VERB',
#   'PRT',
#   'VERB',
#   'ADP',
#   'PROPN',
#   'AUX',
#   'ADV',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'PROPN',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   '.',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PRT',
#   'VERB',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT'],
#  ['CONJ',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ...]

# %%
true_tags_list = []

for sentence in df_test["sen"]:
    tags_only = []
    for word, tag in sentence:
        tags_only.append(tag)
    true_tags_list.append(tags_only)

# %%
total_words = 0
correct_predictions = 0

for i in range(len(true_tags_list)):
    for j in range(len(true_tags_list[i])):
        total_words += 1
        if true_tags_list[i][j] == predicted_tags_list[i][j]:
            correct_predictions += 1

accuracy = (correct_predictions / total_words) * 100
print(f"Viterbi Algorithm Accuracy: {accuracy:.2f}%")
# Out:
# Viterbi Algorithm Accuracy: 87.59%

# %% [markdown]
# # Summary
#
# ### Accuracy without Lemmatization : 88.98%
# ### Accuracy with Lemmatization : 87.59%
